# %% [markdown]
# # Read and save outputs

# %%
# python libraries
import glob
import numpy as np
import h5py
import math
import time
import matplotlib.pyplot as plt
import os
import getpass

# open access to cernbox
os.system("echo %s| kinit" %getpass.getpass())
# Out:
# ········
# 0

# %% [markdown]
# ## Functions:

# %%
def collect_t(DIR_IN, DIR_OUT):
    '''
    For each toy the function reads the .txt file where the final value for the variable t=-2*loss is saved. 
    It then associates a label to each toy.
    The array of the t values (tvalues) and the array of labels (files_id) are saved in an .h5 file.
    
    DIR_IN: directory where all the toys' outputs are saved
    DIR_OUT: directory where to save the .h5 output file
    
    The function returns the array of labels.
    '''
    tvalues = np.array([])
    files_id = np.array([])
    FILE_TITLE=''
    for fileIN in glob.glob("%s/*_t.txt" %DIR_IN):
        #print(fileIN)
        f = open(fileIN)
        lines = f.readlines()
        file_id=  fileIN.split('/')[-1]
        FILE_TITLE = fileIN.split('/')[-2]
        file_id = file_id.replace('_t.txt', '')
        #print(file_id)
        if len(lines)==0:
            continue
        t = float(lines[0])
        #print(file_id)
        if(np.isnan(np.array([t]))): 
            continue    
        tvalues = np.append(tvalues, t)
        files_id = np.append(files_id, file_id)
        
    # save tvalues in a h5 file
    f = h5py.File(DIR_OUT+ FILE_TITLE+'_tvalues.h5', 'w')
    f.create_dataset('tvalues', data=tvalues, compression='gzip')
    f.create_dataset('files_id', data=files_id, compression='gzip')
    f.close()
    
    return files_id

def collect_history(files_id, DIR_IN, patience):
    '''
    For each toy whose file ID is in the array files_id, 
    the function collects the history of the loss and saves t=-2*loss at the check points.
    
    files_id: array of toy labels 
    DIR_IN: directory where all the toys' outputs are saved
    patience: interval between two check points (epochs)
    
    The function returns a 2D-array with final shape (nr toys, nr check points).
    '''
    tdistributions_check =np.array([])
    cnt=0
    for file_id in files_id:
        history_file = DIR_IN+file_id+'_history'+str(patience)+'.h5'
        #print(history_file)
        f = h5py.File(history_file)
        loss = f.get("loss")
        if not loss:
            continue
        loss = np.array(loss)
        loss = np.expand_dims(loss, axis=1)
        if not cnt:
            # initialize the array at the first iteration
            tdistributions_check = -2*loss
        else:
            # just append to tdistributions_check
            tdistributions_check = np.concatenate((tdistributions_check, -2*loss), axis=1)
        print(str(cnt)+': toy '+file_id+' loaded.')
        cnt = cnt+1
        #print(tdistributions_check.shape)
    print('Final history array shape')
    print('(nr toys, nr check points)')
    print(tdistributions_check.T.shape)
    return tdistributions_check.T

def Save_to_h5(DIR_OUT, file_name, extension, patience, tvalues_check):
    '''
    The function save the 2D-array of the loss histories in an .h5 file.
    
    DIR_OUT: directory where to save the output file
    file_name: output file name
    extension: label to be appended to the file_name
    
    No return.
    '''
    epochs_check = []
    nr_check_points = tvalues_check.shape[1]
    for i in range(nr_check_points):
        epoch_check = patience*(i+1)
        epochs_check.append(epoch_check)
        
    log_file = DIR_OUT+file_name+extension+'.h5' #'_tvalues_check.h5'
    print(log_file)
    f = h5py.File(log_file,"w")
    for i in range(tvalues_check.shape[1]):
        f.create_dataset(str(epochs_check[i]), data=tvalues_check[:, i], compression='gzip')
    f.close()
    print('Saved to file: ' +file_name+extension+'.h5')
    return

# %% [markdown]
# ## Set parameters:

# %%
# output directory
output_path='../BINNED/Zsamples/validation_CHI2/Scanning_outputs/300GeV/'
if not os.path.exists(output_path):
    os.makedirs(output_path)

# background only directory
DIR_INPUT_B = '/eos/user/g/ggrosso/BINNED/Zsamples/300GeV/Z_5D_corrected_std_patience5000_ref1000000_bkg100000_sig0_epochs300000_latent5_layers3_wclip1.9/'
# signal+background directory
DIR_INPUT_SB = '/eos/user/g/ggrosso/BINNED/Zsamples/300GeV/Z_5D_std_corrected_patience5000_ref1000000_bkg100000_sig40_epochs300000_latent5_layers3_wclip1.9/'

patience_B = DIR_INPUT_B.split("patience",1)[1] 
patience_B = patience_B.split("_",1)[0]
patience_SB = DIR_INPUT_SB.split("patience",1)[1] 
patience_SB = patience_SB.split("_",1)[0]

# %% [markdown]
# ## Read and Save - BKG only

# %%
if not DIR_INPUT_B.endswith('/'):
    DIR_INPUT_B=DIR_INPUT_B+'/'
    
title_B = DIR_INPUT_B.split('/')[-2]
print(title_B)

files_id_B = collect_t(DIR_INPUT_B, output_path)
print('Loaded') 
tvalues_check_B = collect_history(files_id_B, DIR_INPUT_B, int(patience_B))
# Out:
# Z_5D_corrected_std_patience5000_ref1000000_bkg100000_sig0_epochs300000_latent5_layers3_wclip1.9
# Loaded
# 0: toy Toy5D_patience5000_1000000ref_100000_0_0 loaded.
# 1: toy Toy5D_patience5000_1000000ref_100000_0_100 loaded.
# 2: toy Toy5D_patience5000_1000000ref_100000_0_101 loaded.
# 3: toy Toy5D_patience5000_1000000ref_100000_0_102 loaded.
# 4: toy Toy5D_patience5000_1000000ref_100000_0_103 loaded.
# 5: toy Toy5D_patience5000_1000000ref_100000_0_104 loaded.
# 6: toy Toy5D_patience5000_1000000ref_100000_0_105 loaded.
# 7: toy Toy5D_patience5000_1000000ref_100000_0_106 loaded.
# 8: toy Toy5D_patience5000_1000000ref_100000_0_107 loaded.
# 9: toy Toy5D_patience5000_1000000ref_100000_0_108 loaded.
# 10: toy Toy5D_patience5000_1000000ref_100000_0_109 loaded.
# 11: toy Toy5D_patience5000_1000000ref_100000_0_10 loaded.
# 12: toy Toy5D_patience5000_1000000ref_100000_0_110 loaded.
# 13: toy Toy5D_patience5000_1000000ref_100000_0_111 loaded.
# 14: toy Toy5D_patience5000_1000000ref_100000_0_112 loaded.
# 15: toy Toy5D_patience5000_1000000ref_100000_0_113 loaded.
# 16: toy Toy5D_patience5000_1000000ref_100000_0_114 loaded.
# 17: toy Toy5D_patience5000_1000000ref_100000_0_116 loaded.
# 18: toy Toy5D_patience5000_1000000ref_100000_0_117 loaded.
# 19: toy Toy5D_patience5000_1000000ref_100000_0_118 loaded.
# 20: toy Toy5D_patience5000_1000000ref_100000_0_119 loaded.
# 21: toy Toy5D_patience5000_1000000ref_100000_0_11 loaded.
# 22: toy Toy5D_patience5000_1000000ref_100000_0_121 loaded.
# 23: toy Toy5D_patience5000_1000000ref_100000_0_122 loaded.
# 24: toy Toy5D_patience5000_1000000ref_100000_0_126 loaded.
# 25: toy Toy5D_patience5000_1000000ref_100000_0_127 loaded.
# 26: toy Toy5D_patience5000_1000000ref_100000_0_128 loaded.
# 27: toy Toy5D_patience5000_1000000ref_100000_0_129 loaded.
# 28: toy Toy5D_patience5000_1000000ref_100000_0_130 loaded.
# 29: toy Toy5D_patience5000_1000000ref_100000_0_131 loaded.
# 30: toy Toy5D_patience5000_1000000ref_100000_0_132 loaded.
# 31: toy Toy5D_patience5000_1000000ref_100000_0_133 loaded.
# 32: toy Toy5D_patience5000_1000000ref_100000_0_134 loaded.
# 33: toy Toy5D_patience5000_1000000ref_100000_0_135 loaded.
# 34: toy Toy5D_patience5000_1000000ref_100000_0_136 loaded.
# 35: toy Toy5D_patience5000_1000000ref_100000_0_138 loaded.
# 36: toy Toy5D_patience5000_1000000ref_100000_0_139 loaded.
# 37: toy Toy5D_patience5000_1000000ref_100000_0_140 loaded.
# 38: toy Toy5D_patience5000_1000000ref_100000_0_141 loaded.
# 39: toy Toy5D_patience5000_1000000ref_100000_0_143 loaded.
# 40: toy Toy5D_patience5000_1000000ref_100000_0_144 loaded.
# 41: toy Toy5D_patience5000_1000000ref_100000_0_146 loaded.
# 42: toy Toy5D_patience5000_1000000ref_100000_0_147 loaded.
# 43: toy Toy5D_patience5000_1000000ref_100000_0_148 loaded.
# 44: toy Toy5D_patience5000_1000000ref_100000_0_149 loaded.
# 45: toy Toy5D_patience5000_1000000ref_100000_0_150 loaded.
# 46: toy Toy5D_patience5000_1000000ref_100000_0_151 loaded.
# 47: toy Toy5D_patience5000_1000000ref_100000_0_152 loaded.
# 48: toy Toy5D_patience5000_1000000ref_100000_0_153 loaded.
# 49: toy Toy5D_patience5000_1000000ref_100000_0_154 loaded.
# 50: toy Toy5D_patience5000_1000000ref_100000_0_155 loaded.
# 51: toy Toy5D_patience5000_1000000ref_100000_0_156 loaded.
# 52: toy Toy5D_patience5000_1000000ref_100000_0_158 loaded.
# 53: toy Toy5D_patience5000_1000000ref_100000_0_161 loaded.
# 54: toy Toy5D_patience5000_1000000ref_100000_0_162 loaded.
# 55: toy Toy5D_patience5000_1000000ref_100000_0_163 loaded.
# 56: toy Toy5D_patience5000_1000000ref_100000_0_164 loaded.
# 57: toy Toy5D_patience5000_1000000ref_100000_0_165 loaded.
# 58: toy Toy5D_patience5000_1000000ref_100000_0_166 loaded.
# 59: toy Toy5D_patience5000_1000000ref_100000_0_167 loaded.
# 60: toy Toy5D_patience5000_1000000ref_100000_0_168 loaded.
# 61: toy Toy5D_patience5000_1000000ref_100000_0_169 loaded.
# 62: toy Toy5D_patience5000_1000000ref_100000_0_16 loaded.
# 63: toy Toy5D_patience5000_1000000ref_100000_0_170 loaded.
# 64: toy Toy5D_patience5000_1000000ref_100000_0_172 loaded.
# 65: toy Toy5D_patience5000_1000000ref_100000_0_173 loaded.
# 66: toy Toy5D_patience5000_1000000ref_100000_0_174 loaded.
# 67: toy Toy5D_patience5000_1000000ref_100000_0_175 loaded.
# 68: toy Toy5D_patience5000_1000000ref_100000_0_176 loaded.
# 69: toy Toy5D_patience5000_1000000ref_100000_0_177 loaded.
# 70: toy Toy5D_patience5000_1000000ref_100000_0_178 loaded.
# 71: toy Toy5D_patience5000_1000000ref_100000_0_179 loaded.
# 72: toy Toy5D_patience5000_1000000ref_100000_0_17 loaded.
# 73: toy Toy5D_patience5000_1000000ref_100000_0_180 loaded.
# 74: toy Toy5D_patience5000_1000000ref_100000_0_181 loaded.
# 75: toy Toy5D_patience5000_1000000ref_100000_0_182 loaded.
# 76: toy Toy5D_patience5000_1000000ref_100000_0_183 loaded.
# 77: toy Toy5D_patience5000_1000000ref_100000_0_184 loaded.
# 78: toy Toy5D_patience5000_1000000ref_100000_0_185 loaded.
# 79: toy Toy5D_patience5000_1000000ref_100000_0_186 loaded.
# 80: toy Toy5D_patience5000_1000000ref_100000_0_187 loaded.
# 81: toy Toy5D_patience5000_1000000ref_100000_0_188 loaded.
# 82: toy Toy5D_patience5000_1000000ref_100000_0_189 loaded.
# 83: toy Toy5D_patience5000_1000000ref_100000_0_18 loaded.
# 84: toy Toy5D_patience5000_1000000ref_100000_0_190 loaded.
# 85: toy Toy5D_patience5000_1000000ref_100000_0_191 loaded.
# 86: toy Toy5D_patience5000_1000000ref_100000_0_192 loaded.
# 87: toy Toy5D_patience5000_1000000ref_100000_0_193 loaded.
# 88: toy Toy5D_patience5000_1000000ref_100000_0_194 loaded.
# 89: toy Toy5D_patience5000_1000000ref_100000_0_195 loaded.
# 90: toy Toy5D_patience5000_1000000ref_100000_0_196 loaded.
# 91: toy Toy5D_patience5000_1000000ref_100000_0_198 loaded.
# 92: toy Toy5D_patience5000_1000000ref_100000_0_199 loaded.
# 93: toy Toy5D_patience5000_1000000ref_100000_0_1 loaded.
# 94: toy Toy5D_patience5000_1000000ref_100000_0_200 loaded.
# 95: toy Toy5D_patience5000_1000000ref_100000_0_202 loaded.
# 96: toy Toy5D_patience5000_1000000ref_100000_0_203 loaded.
# 97: toy Toy5D_patience5000_1000000ref_100000_0_204 loaded.
# 98: toy Toy5D_patience5000_1000000ref_100000_0_205 loaded.
# 99: toy Toy5D_patience5000_1000000ref_100000_0_206 loaded.
# 100: toy Toy5D_patience5000_1000000ref_100000_0_207 loaded.
# 101: toy Toy5D_patience5000_1000000ref_100000_0_208 loaded.
# 102: toy Toy5D_patience5000_1000000ref_100000_0_209 loaded.
# 103: toy Toy5D_patience5000_1000000ref_100000_0_20 loaded.
# 104: toy Toy5D_patience5000_1000000ref_100000_0_210 loaded.
# 105: toy Toy5D_patience5000_1000000ref_100000_0_212 loaded.
# 106: toy Toy5D_patience5000_1000000ref_100000_0_213 loaded.
# 107: toy Toy5D_patience5000_1000000ref_100000_0_214 loaded.
# 108: toy Toy5D_patience5000_1000000ref_100000_0_215 loaded.
# 109: toy Toy5D_patience5000_1000000ref_100000_0_216 loaded.
# 110: toy Toy5D_patience5000_1000000ref_100000_0_217 loaded.
# 111: toy Toy5D_patience5000_1000000ref_100000_0_218 loaded.
# 112: toy Toy5D_patience5000_1000000ref_100000_0_219 loaded.
# 113: toy Toy5D_patience5000_1000000ref_100000_0_21 loaded.
# 114: toy Toy5D_patience5000_1000000ref_100000_0_221 loaded.
# 115: toy Toy5D_patience5000_1000000ref_100000_0_222 loaded.
# 116: toy Toy5D_patience5000_1000000ref_100000_0_225 loaded.
# 117: toy Toy5D_patience5000_1000000ref_100000_0_229 loaded.
# 118: toy Toy5D_patience5000_1000000ref_100000_0_22 loaded.
# 119: toy Toy5D_patience5000_1000000ref_100000_0_232 loaded.
# 120: toy Toy5D_patience5000_1000000ref_100000_0_233 loaded.
# 121: toy Toy5D_patience5000_1000000ref_100000_0_234 loaded.
# 122: toy Toy5D_patience5000_1000000ref_100000_0_235 loaded.
# 123: toy Toy5D_patience5000_1000000ref_100000_0_236 loaded.
# 124: toy Toy5D_patience5000_1000000ref_100000_0_237 loaded.
# 125: toy Toy5D_patience5000_1000000ref_100000_0_238 loaded.
# 126: toy Toy5D_patience5000_1000000ref_100000_0_239 loaded.
# 127: toy Toy5D_patience5000_1000000ref_100000_0_23 loaded.
# 128: toy Toy5D_patience5000_1000000ref_100000_0_240 loaded.
# 129: toy Toy5D_patience5000_1000000ref_100000_0_241 loaded.
# 130: toy Toy5D_patience5000_1000000ref_100000_0_242 loaded.
# 131: toy Toy5D_patience5000_1000000ref_100000_0_243 loaded.
# 132: toy Toy5D_patience5000_1000000ref_100000_0_244 loaded.
# 133: toy Toy5D_patience5000_1000000ref_100000_0_245 loaded.
# 134: toy Toy5D_patience5000_1000000ref_100000_0_246 loaded.
# 135: toy Toy5D_patience5000_1000000ref_100000_0_247 loaded.
# 136: toy Toy5D_patience5000_1000000ref_100000_0_248 loaded.
# 137: toy Toy5D_patience5000_1000000ref_100000_0_249 loaded.
# 138: toy Toy5D_patience5000_1000000ref_100000_0_24 loaded.
# 139: toy Toy5D_patience5000_1000000ref_100000_0_25 loaded.
# 140: toy Toy5D_patience5000_1000000ref_100000_0_27 loaded.
# 141: toy Toy5D_patience5000_1000000ref_100000_0_28 loaded.
# 142: toy Toy5D_patience5000_1000000ref_100000_0_29 loaded.
# 143: toy Toy5D_patience5000_1000000ref_100000_0_2 loaded.
# 144: toy Toy5D_patience5000_1000000ref_100000_0_30 loaded.
# 145: toy Toy5D_patience5000_1000000ref_100000_0_31 loaded.
# 146: toy Toy5D_patience5000_1000000ref_100000_0_32 loaded.
# 147: toy Toy5D_patience5000_1000000ref_100000_0_33 loaded.
# 148: toy Toy5D_patience5000_1000000ref_100000_0_34 loaded.
# 149: toy Toy5D_patience5000_1000000ref_100000_0_35 loaded.
# 150: toy Toy5D_patience5000_1000000ref_100000_0_36 loaded.
# 151: toy Toy5D_patience5000_1000000ref_100000_0_38 loaded.
# 152: toy Toy5D_patience5000_1000000ref_100000_0_39 loaded.
# 153: toy Toy5D_patience5000_1000000ref_100000_0_3 loaded.
# 154: toy Toy5D_patience5000_1000000ref_100000_0_40 loaded.
# 155: toy Toy5D_patience5000_1000000ref_100000_0_41 loaded.
# 156: toy Toy5D_patience5000_1000000ref_100000_0_42 loaded.
# 157: toy Toy5D_patience5000_1000000ref_100000_0_43 loaded.
# 158: toy Toy5D_patience5000_1000000ref_100000_0_44 loaded.
# 159: toy Toy5D_patience5000_1000000ref_100000_0_45 loaded.
# 160: toy Toy5D_patience5000_1000000ref_100000_0_46 loaded.
# 161: toy Toy5D_patience5000_1000000ref_100000_0_47 loaded.
# 162: toy Toy5D_patience5000_1000000ref_100000_0_48 loaded.
# 163: toy Toy5D_patience5000_1000000ref_100000_0_49 loaded.
# 164: toy Toy5D_patience5000_1000000ref_100000_0_4 loaded.
# 165: toy Toy5D_patience5000_1000000ref_100000_0_50 loaded.
# 166: toy Toy5D_patience5000_1000000ref_100000_0_51 loaded.
# 167: toy Toy5D_patience5000_1000000ref_100000_0_52 loaded.
# 168: toy Toy5D_patience5000_1000000ref_100000_0_53 loaded.
# 169: toy Toy5D_patience5000_1000000ref_100000_0_54 loaded.
# 170: toy Toy5D_patience5000_1000000ref_100000_0_55 loaded.
# 171: toy Toy5D_patience5000_1000000ref_100000_0_56 loaded.
# 172: toy Toy5D_patience5000_1000000ref_100000_0_57 loaded.
# 173: toy Toy5D_patience5000_1000000ref_100000_0_58 loaded.
# 174: toy Toy5D_patience5000_1000000ref_100000_0_59 loaded.
# 175: toy Toy5D_patience5000_1000000ref_100000_0_61 loaded.
# 176: toy Toy5D_patience5000_1000000ref_100000_0_62 loaded.
# 177: toy Toy5D_patience5000_1000000ref_100000_0_63 loaded.
# 178: toy Toy5D_patience5000_1000000ref_100000_0_65 loaded.
# 179: toy Toy5D_patience5000_1000000ref_100000_0_66 loaded.
# 180: toy Toy5D_patience5000_1000000ref_100000_0_68 loaded.
# 181: toy Toy5D_patience5000_1000000ref_100000_0_69 loaded.
# 182: toy Toy5D_patience5000_1000000ref_100000_0_70 loaded.
# 183: toy Toy5D_patience5000_1000000ref_100000_0_71 loaded.
# 184: toy Toy5D_patience5000_1000000ref_100000_0_72 loaded.
# 185: toy Toy5D_patience5000_1000000ref_100000_0_73 loaded.
# 186: toy Toy5D_patience5000_1000000ref_100000_0_74 loaded.
# 187: toy Toy5D_patience5000_1000000ref_100000_0_75 loaded.
# 188: toy Toy5D_patience5000_1000000ref_100000_0_76 loaded.
# 189: toy Toy5D_patience5000_1000000ref_100000_0_77 loaded.
# 190: toy Toy5D_patience5000_1000000ref_100000_0_78 loaded.
# 191: toy Toy5D_patience5000_1000000ref_100000_0_79 loaded.
# 192: toy Toy5D_patience5000_1000000ref_100000_0_7 loaded.
# 193: toy Toy5D_patience5000_1000000ref_100000_0_80 loaded.
# 194: toy Toy5D_patience5000_1000000ref_100000_0_81 loaded.
# 195: toy Toy5D_patience5000_1000000ref_100000_0_82 loaded.
# 196: toy Toy5D_patience5000_1000000ref_100000_0_83 loaded.
# 197: toy Toy5D_patience5000_1000000ref_100000_0_84 loaded.
# 198: toy Toy5D_patience5000_1000000ref_100000_0_85 loaded.
# 199: toy Toy5D_patience5000_1000000ref_100000_0_86 loaded.
# 200: toy Toy5D_patience5000_1000000ref_100000_0_87 loaded.
# 201: toy Toy5D_patience5000_1000000ref_100000_0_88 loaded.
# 202: toy Toy5D_patience5000_1000000ref_100000_0_89 loaded.
# 203: toy Toy5D_patience5000_1000000ref_100000_0_8 loaded.
# 204: toy Toy5D_patience5000_1000000ref_100000_0_90 loaded.
# 205: toy Toy5D_patience5000_1000000ref_100000_0_91 loaded.
# 206: toy Toy5D_patience5000_1000000ref_100000_0_92 loaded.
# 207: toy Toy5D_patience5000_1000000ref_100000_0_93 loaded.
# 208: toy Toy5D_patience5000_1000000ref_100000_0_94 loaded.
# 209: toy Toy5D_patience5000_1000000ref_100000_0_95 loaded.
# 210: toy Toy5D_patience5000_1000000ref_100000_0_96 loaded.
# 211: toy Toy5D_patience5000_1000000ref_100000_0_97 loaded.
# 212: toy Toy5D_patience5000_1000000ref_100000_0_98 loaded.
# 213: toy Toy5D_patience5000_1000000ref_100000_0_99 loaded.
# 214: toy Toy5D_patience5000_1000000ref_100000_0_9 loaded.
# Final history array shape
# (nr toys, nr check points)
# (215, 60)

# %%
Save_to_h5(output_path, title_B, '_tvalues_check', int(patience_B), tvalues_check_B)
# Out:
# ../BINNED/Zsamples/validation_CHI2/Scanning_outputs/300GeV/Z_5D_corrected_std_patience5000_ref1000000_bkg100000_sig0_epochs300000_latent5_layers3_wclip1.9_tvalues_check.h5
# Saved to file: Z_5D_corrected_std_patience5000_ref1000000_bkg100000_sig0_epochs300000_latent5_layers3_wclip1.9_tvalues_check.h5

# %% [markdown]
# ## Read and Save - SIG+BKG

# %%
if not DIR_INPUT_SB.endswith('/'):
    DIR_INPUT_SB=DIR_INPUT_SB+'/'
    
title_SB = DIR_INPUT_SB.split('/')[-2]
print(title_SB)

files_id_SB = collect_t(DIR_INPUT_SB, output_path)
print('Loaded') 
tvalues_check_SB = collect_history(files_id_SB, DIR_INPUT_SB, int(patience_SB))
# Out:
# Z_5D_std_corrected_patience5000_ref1000000_bkg100000_sig40_epochs300000_latent5_layers3_wclip1.9
# Loaded
# 0: toy Toy5D_patience5000_1000000ref_100000_40_100 loaded.
# 1: toy Toy5D_patience5000_1000000ref_100000_40_101 loaded.
# 2: toy Toy5D_patience5000_1000000ref_100000_40_102 loaded.
# 3: toy Toy5D_patience5000_1000000ref_100000_40_103 loaded.
# 4: toy Toy5D_patience5000_1000000ref_100000_40_104 loaded.
# 5: toy Toy5D_patience5000_1000000ref_100000_40_105 loaded.
# 6: toy Toy5D_patience5000_1000000ref_100000_40_106 loaded.
# 7: toy Toy5D_patience5000_1000000ref_100000_40_107 loaded.
# 8: toy Toy5D_patience5000_1000000ref_100000_40_108 loaded.
# 9: toy Toy5D_patience5000_1000000ref_100000_40_109 loaded.
# 10: toy Toy5D_patience5000_1000000ref_100000_40_10 loaded.
# 11: toy Toy5D_patience5000_1000000ref_100000_40_110 loaded.
# 12: toy Toy5D_patience5000_1000000ref_100000_40_111 loaded.
# 13: toy Toy5D_patience5000_1000000ref_100000_40_112 loaded.
# 14: toy Toy5D_patience5000_1000000ref_100000_40_113 loaded.
# 15: toy Toy5D_patience5000_1000000ref_100000_40_114 loaded.
# 16: toy Toy5D_patience5000_1000000ref_100000_40_115 loaded.
# 17: toy Toy5D_patience5000_1000000ref_100000_40_116 loaded.
# 18: toy Toy5D_patience5000_1000000ref_100000_40_118 loaded.
# 19: toy Toy5D_patience5000_1000000ref_100000_40_119 loaded.
# 20: toy Toy5D_patience5000_1000000ref_100000_40_11 loaded.
# 21: toy Toy5D_patience5000_1000000ref_100000_40_120 loaded.
# 22: toy Toy5D_patience5000_1000000ref_100000_40_121 loaded.
# 23: toy Toy5D_patience5000_1000000ref_100000_40_122 loaded.
# 24: toy Toy5D_patience5000_1000000ref_100000_40_123 loaded.
# 25: toy Toy5D_patience5000_1000000ref_100000_40_124 loaded.
# 26: toy Toy5D_patience5000_1000000ref_100000_40_125 loaded.
# 27: toy Toy5D_patience5000_1000000ref_100000_40_126 loaded.
# 28: toy Toy5D_patience5000_1000000ref_100000_40_127 loaded.
# 29: toy Toy5D_patience5000_1000000ref_100000_40_128 loaded.
# 30: toy Toy5D_patience5000_1000000ref_100000_40_129 loaded.
# 31: toy Toy5D_patience5000_1000000ref_100000_40_12 loaded.
# 32: toy Toy5D_patience5000_1000000ref_100000_40_130 loaded.
# 33: toy Toy5D_patience5000_1000000ref_100000_40_131 loaded.
# 34: toy Toy5D_patience5000_1000000ref_100000_40_132 loaded.
# 35: toy Toy5D_patience5000_1000000ref_100000_40_133 loaded.
# 36: toy Toy5D_patience5000_1000000ref_100000_40_134 loaded.
# 37: toy Toy5D_patience5000_1000000ref_100000_40_135 loaded.
# 38: toy Toy5D_patience5000_1000000ref_100000_40_136 loaded.
# 39: toy Toy5D_patience5000_1000000ref_100000_40_137 loaded.
# 40: toy Toy5D_patience5000_1000000ref_100000_40_138 loaded.
# 41: toy Toy5D_patience5000_1000000ref_100000_40_139 loaded.
# 42: toy Toy5D_patience5000_1000000ref_100000_40_13 loaded.
# 43: toy Toy5D_patience5000_1000000ref_100000_40_140 loaded.
# 44: toy Toy5D_patience5000_1000000ref_100000_40_141 loaded.
# 45: toy Toy5D_patience5000_1000000ref_100000_40_142 loaded.
# 46: toy Toy5D_patience5000_1000000ref_100000_40_143 loaded.
# 47: toy Toy5D_patience5000_1000000ref_100000_40_144 loaded.
# 48: toy Toy5D_patience5000_1000000ref_100000_40_145 loaded.
# 49: toy Toy5D_patience5000_1000000ref_100000_40_146 loaded.
# 50: toy Toy5D_patience5000_1000000ref_100000_40_147 loaded.
# 51: toy Toy5D_patience5000_1000000ref_100000_40_148 loaded.
# 52: toy Toy5D_patience5000_1000000ref_100000_40_14 loaded.
# 53: toy Toy5D_patience5000_1000000ref_100000_40_151 loaded.
# 54: toy Toy5D_patience5000_1000000ref_100000_40_152 loaded.
# 55: toy Toy5D_patience5000_1000000ref_100000_40_153 loaded.
# 56: toy Toy5D_patience5000_1000000ref_100000_40_154 loaded.
# 57: toy Toy5D_patience5000_1000000ref_100000_40_155 loaded.
# 58: toy Toy5D_patience5000_1000000ref_100000_40_156 loaded.
# 59: toy Toy5D_patience5000_1000000ref_100000_40_157 loaded.
# 60: toy Toy5D_patience5000_1000000ref_100000_40_158 loaded.
# 61: toy Toy5D_patience5000_1000000ref_100000_40_15 loaded.
# 62: toy Toy5D_patience5000_1000000ref_100000_40_160 loaded.
# 63: toy Toy5D_patience5000_1000000ref_100000_40_161 loaded.
# 64: toy Toy5D_patience5000_1000000ref_100000_40_162 loaded.
# 65: toy Toy5D_patience5000_1000000ref_100000_40_163 loaded.
# 66: toy Toy5D_patience5000_1000000ref_100000_40_164 loaded.
# 67: toy Toy5D_patience5000_1000000ref_100000_40_165 loaded.
# 68: toy Toy5D_patience5000_1000000ref_100000_40_167 loaded.
# 69: toy Toy5D_patience5000_1000000ref_100000_40_168 loaded.
# 70: toy Toy5D_patience5000_1000000ref_100000_40_169 loaded.
# 71: toy Toy5D_patience5000_1000000ref_100000_40_170 loaded.
# 72: toy Toy5D_patience5000_1000000ref_100000_40_171 loaded.
# 73: toy Toy5D_patience5000_1000000ref_100000_40_172 loaded.
# 74: toy Toy5D_patience5000_1000000ref_100000_40_173 loaded.
# 75: toy Toy5D_patience5000_1000000ref_100000_40_174 loaded.
# 76: toy Toy5D_patience5000_1000000ref_100000_40_175 loaded.
# 77: toy Toy5D_patience5000_1000000ref_100000_40_176 loaded.
# 78: toy Toy5D_patience5000_1000000ref_100000_40_177 loaded.
# 79: toy Toy5D_patience5000_1000000ref_100000_40_178 loaded.
# 80: toy Toy5D_patience5000_1000000ref_100000_40_179 loaded.
# 81: toy Toy5D_patience5000_1000000ref_100000_40_17 loaded.
# 82: toy Toy5D_patience5000_1000000ref_100000_40_180 loaded.
# 83: toy Toy5D_patience5000_1000000ref_100000_40_181 loaded.
# 84: toy Toy5D_patience5000_1000000ref_100000_40_183 loaded.
# 85: toy Toy5D_patience5000_1000000ref_100000_40_184 loaded.
# 86: toy Toy5D_patience5000_1000000ref_100000_40_185 loaded.
# 87: toy Toy5D_patience5000_1000000ref_100000_40_186 loaded.
# 88: toy Toy5D_patience5000_1000000ref_100000_40_187 loaded.
# 89: toy Toy5D_patience5000_1000000ref_100000_40_188 loaded.
# 90: toy Toy5D_patience5000_1000000ref_100000_40_189 loaded.
# 91: toy Toy5D_patience5000_1000000ref_100000_40_18 loaded.
# 92: toy Toy5D_patience5000_1000000ref_100000_40_190 loaded.
# 93: toy Toy5D_patience5000_1000000ref_100000_40_191 loaded.
# 94: toy Toy5D_patience5000_1000000ref_100000_40_192 loaded.
# 95: toy Toy5D_patience5000_1000000ref_100000_40_193 loaded.
# 96: toy Toy5D_patience5000_1000000ref_100000_40_194 loaded.
# 97: toy Toy5D_patience5000_1000000ref_100000_40_195 loaded.
# 98: toy Toy5D_patience5000_1000000ref_100000_40_196 loaded.
# 99: toy Toy5D_patience5000_1000000ref_100000_40_197 loaded.
# 100: toy Toy5D_patience5000_1000000ref_100000_40_198 loaded.
# 101: toy Toy5D_patience5000_1000000ref_100000_40_199 loaded.
# 102: toy Toy5D_patience5000_1000000ref_100000_40_19 loaded.
# 103: toy Toy5D_patience5000_1000000ref_100000_40_1 loaded.
# 104: toy Toy5D_patience5000_1000000ref_100000_40_200 loaded.
# 105: toy Toy5D_patience5000_1000000ref_100000_40_201 loaded.
# 106: toy Toy5D_patience5000_1000000ref_100000_40_204 loaded.
# 107: toy Toy5D_patience5000_1000000ref_100000_40_205 loaded.
# 108: toy Toy5D_patience5000_1000000ref_100000_40_206 loaded.
# 109: toy Toy5D_patience5000_1000000ref_100000_40_207 loaded.
# 110: toy Toy5D_patience5000_1000000ref_100000_40_208 loaded.
# 111: toy Toy5D_patience5000_1000000ref_100000_40_209 loaded.
# 112: toy Toy5D_patience5000_1000000ref_100000_40_20 loaded.
# 113: toy Toy5D_patience5000_1000000ref_100000_40_210 loaded.
# 114: toy Toy5D_patience5000_1000000ref_100000_40_214 loaded.
# 115: toy Toy5D_patience5000_1000000ref_100000_40_217 loaded.
# 116: toy Toy5D_patience5000_1000000ref_100000_40_218 loaded.
# 117: toy Toy5D_patience5000_1000000ref_100000_40_219 loaded.
# 118: toy Toy5D_patience5000_1000000ref_100000_40_21 loaded.
# 119: toy Toy5D_patience5000_1000000ref_100000_40_220 loaded.
# 120: toy Toy5D_patience5000_1000000ref_100000_40_221 loaded.
# 121: toy Toy5D_patience5000_1000000ref_100000_40_222 loaded.
# 122: toy Toy5D_patience5000_1000000ref_100000_40_223 loaded.
# 123: toy Toy5D_patience5000_1000000ref_100000_40_224 loaded.
# 124: toy Toy5D_patience5000_1000000ref_100000_40_225 loaded.
# 125: toy Toy5D_patience5000_1000000ref_100000_40_227 loaded.
# 126: toy Toy5D_patience5000_1000000ref_100000_40_228 loaded.
# 127: toy Toy5D_patience5000_1000000ref_100000_40_229 loaded.
# 128: toy Toy5D_patience5000_1000000ref_100000_40_230 loaded.
# 129: toy Toy5D_patience5000_1000000ref_100000_40_231 loaded.
# 130: toy Toy5D_patience5000_1000000ref_100000_40_232 loaded.
# 131: toy Toy5D_patience5000_1000000ref_100000_40_233 loaded.
# 132: toy Toy5D_patience5000_1000000ref_100000_40_234 loaded.
# 133: toy Toy5D_patience5000_1000000ref_100000_40_235 loaded.
# 134: toy Toy5D_patience5000_1000000ref_100000_40_236 loaded.
# 135: toy Toy5D_patience5000_1000000ref_100000_40_238 loaded.
# 136: toy Toy5D_patience5000_1000000ref_100000_40_239 loaded.
# 137: toy Toy5D_patience5000_1000000ref_100000_40_23 loaded.
# 138: toy Toy5D_patience5000_1000000ref_100000_40_241 loaded.
# 139: toy Toy5D_patience5000_1000000ref_100000_40_242 loaded.
# 140: toy Toy5D_patience5000_1000000ref_100000_40_244 loaded.
# 141: toy Toy5D_patience5000_1000000ref_100000_40_245 loaded.
# 142: toy Toy5D_patience5000_1000000ref_100000_40_248 loaded.
# 143: toy Toy5D_patience5000_1000000ref_100000_40_249 loaded.
# 144: toy Toy5D_patience5000_1000000ref_100000_40_24 loaded.
# 145: toy Toy5D_patience5000_1000000ref_100000_40_26 loaded.
# 146: toy Toy5D_patience5000_1000000ref_100000_40_27 loaded.
# 147: toy Toy5D_patience5000_1000000ref_100000_40_28 loaded.
# 148: toy Toy5D_patience5000_1000000ref_100000_40_29 loaded.
# 149: toy Toy5D_patience5000_1000000ref_100000_40_2 loaded.
# 150: toy Toy5D_patience5000_1000000ref_100000_40_30 loaded.
# 151: toy Toy5D_patience5000_1000000ref_100000_40_31 loaded.
# 152: toy Toy5D_patience5000_1000000ref_100000_40_32 loaded.
# 153: toy Toy5D_patience5000_1000000ref_100000_40_33 loaded.
# 154: toy Toy5D_patience5000_1000000ref_100000_40_34 loaded.
# 155: toy Toy5D_patience5000_1000000ref_100000_40_35 loaded.
# 156: toy Toy5D_patience5000_1000000ref_100000_40_36 loaded.
# 157: toy Toy5D_patience5000_1000000ref_100000_40_37 loaded.
# 158: toy Toy5D_patience5000_1000000ref_100000_40_38 loaded.
# 159: toy Toy5D_patience5000_1000000ref_100000_40_39 loaded.
# 160: toy Toy5D_patience5000_1000000ref_100000_40_3 loaded.
# 161: toy Toy5D_patience5000_1000000ref_100000_40_40 loaded.
# 162: toy Toy5D_patience5000_1000000ref_100000_40_41 loaded.
# 163: toy Toy5D_patience5000_1000000ref_100000_40_42 loaded.
# 164: toy Toy5D_patience5000_1000000ref_100000_40_43 loaded.
# 165: toy Toy5D_patience5000_1000000ref_100000_40_44 loaded.
# 166: toy Toy5D_patience5000_1000000ref_100000_40_45 loaded.
# 167: toy Toy5D_patience5000_1000000ref_100000_40_46 loaded.
# 168: toy Toy5D_patience5000_1000000ref_100000_40_47 loaded.
# 169: toy Toy5D_patience5000_1000000ref_100000_40_48 loaded.
# 170: toy Toy5D_patience5000_1000000ref_100000_40_49 loaded.
# 171: toy Toy5D_patience5000_1000000ref_100000_40_4 loaded.
# 172: toy Toy5D_patience5000_1000000ref_100000_40_50 loaded.
# 173: toy Toy5D_patience5000_1000000ref_100000_40_51 loaded.
# 174: toy Toy5D_patience5000_1000000ref_100000_40_52 loaded.
# 175: toy Toy5D_patience5000_1000000ref_100000_40_53 loaded.
# 176: toy Toy5D_patience5000_1000000ref_100000_40_54 loaded.
# 177: toy Toy5D_patience5000_1000000ref_100000_40_55 loaded.
# 178: toy Toy5D_patience5000_1000000ref_100000_40_56 loaded.
# 179: toy Toy5D_patience5000_1000000ref_100000_40_57 loaded.
# 180: toy Toy5D_patience5000_1000000ref_100000_40_59 loaded.
# 181: toy Toy5D_patience5000_1000000ref_100000_40_5 loaded.
# 182: toy Toy5D_patience5000_1000000ref_100000_40_60 loaded.
# 183: toy Toy5D_patience5000_1000000ref_100000_40_61 loaded.
# 184: toy Toy5D_patience5000_1000000ref_100000_40_62 loaded.
# 185: toy Toy5D_patience5000_1000000ref_100000_40_63 loaded.
# 186: toy Toy5D_patience5000_1000000ref_100000_40_64 loaded.
# 187: toy Toy5D_patience5000_1000000ref_100000_40_65 loaded.
# 188: toy Toy5D_patience5000_1000000ref_100000_40_66 loaded.
# 189: toy Toy5D_patience5000_1000000ref_100000_40_67 loaded.
# 190: toy Toy5D_patience5000_1000000ref_100000_40_6 loaded.
# 191: toy Toy5D_patience5000_1000000ref_100000_40_70 loaded.
# 192: toy Toy5D_patience5000_1000000ref_100000_40_72 loaded.
# 193: toy Toy5D_patience5000_1000000ref_100000_40_73 loaded.
# 194: toy Toy5D_patience5000_1000000ref_100000_40_74 loaded.
# 195: toy Toy5D_patience5000_1000000ref_100000_40_75 loaded.
# 196: toy Toy5D_patience5000_1000000ref_100000_40_77 loaded.
# 197: toy Toy5D_patience5000_1000000ref_100000_40_78 loaded.
# 198: toy Toy5D_patience5000_1000000ref_100000_40_79 loaded.
# 199: toy Toy5D_patience5000_1000000ref_100000_40_7 loaded.
# 200: toy Toy5D_patience5000_1000000ref_100000_40_80 loaded.
# 201: toy Toy5D_patience5000_1000000ref_100000_40_81 loaded.
# 202: toy Toy5D_patience5000_1000000ref_100000_40_82 loaded.
# 203: toy Toy5D_patience5000_1000000ref_100000_40_83 loaded.
# 204: toy Toy5D_patience5000_1000000ref_100000_40_85 loaded.
# 205: toy Toy5D_patience5000_1000000ref_100000_40_86 loaded.
# 206: toy Toy5D_patience5000_1000000ref_100000_40_87 loaded.
# 207: toy Toy5D_patience5000_1000000ref_100000_40_88 loaded.
# 208: toy Toy5D_patience5000_1000000ref_100000_40_8 loaded.
# 209: toy Toy5D_patience5000_1000000ref_100000_40_90 loaded.
# 210: toy Toy5D_patience5000_1000000ref_100000_40_91 loaded.
# 211: toy Toy5D_patience5000_1000000ref_100000_40_93 loaded.
# 212: toy Toy5D_patience5000_1000000ref_100000_40_94 loaded.
# 213: toy Toy5D_patience5000_1000000ref_100000_40_95 loaded.
# 214: toy Toy5D_patience5000_1000000ref_100000_40_96 loaded.
# 215: toy Toy5D_patience5000_1000000ref_100000_40_97 loaded.
# 216: toy Toy5D_patience5000_1000000ref_100000_40_98 loaded.
# 217: toy Toy5D_patience5000_1000000ref_100000_40_99 loaded.
# 218: toy Toy5D_patience5000_1000000ref_100000_40_9 loaded.
# Final history array shape
# (nr toys, nr check points)
# (219, 60)

# %%
Save_to_h5(output_path, title_SB, '_tvalues_check', int(patience_SB), tvalues_check_SB)
# Out:
# ../BINNED/Zsamples/validation_CHI2/Scanning_outputs/300GeV/Z_5D_std_corrected_patience5000_ref1000000_bkg100000_sig40_epochs300000_latent5_layers3_wclip1.9_tvalues_check.h5
# Saved to file: Z_5D_std_corrected_patience5000_ref1000000_bkg100000_sig40_epochs300000_latent5_layers3_wclip1.9_tvalues_check.h5
